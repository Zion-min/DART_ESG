# %%
import requests
from bs4 import BeautifulSoup

url = 'https://finance.daum.net/api/sector/wics/G451020/stocks?page=1&perPage=30&fieldName=changeRate&order=desc&pagination=true'
headers = {
            'Referer': 'https://finance.daum.net/domestic/wics/G451020',
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36 OPR/58.0.3135.127'
}
response = requests.get(url,headers=headers)

#서버가 제대로 응답했을 때
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('th.first')
    jj= response.json()
    datalist = jj['data']
    for data in jj['data']:
        print(data['name'])
else:
    print(response.status_code)
# Out:
# 에프앤가이드
# 수산아이앤티
# 에스트래픽
# 율호
# 갤럭시아머니트리
# 한솔인티큐브
# 대아티아이
# 삼성에스디에스
# 한국전자인증
# 이루온
# KG이니시스
# 한네트
# 정원엔시스
# 한일네트웍스
# 인포바인
# 현대오토에버
# DB
# 미래아이앤지
# 미래테크놀로지
# 링네트
# 브리지텍
# 민앤지
# 데이타솔루션
# SBI핀테크솔루션즈
# 다우기술
# 다날
# 엔텔스
# 가비아
# 콤텍시스템
# 한국전자금융

# %%
url = 'http://www.cgs.or.kr/business/esg_tab04.jsp?pg=1&pp=10&skey=&svalue=&sfyear=2020&styear=2020&sgtype=&sgrade=#ui_contents'
headers = {
            'Referer': 'https://finance.daum.net/domestic/wics/G451020',
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36 OPR/58.0.3135.127'
}
response = requests.get(url)

#서버가 제대로 응답했을 때
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select('#ui_contents > div.rating-wrap > div.business_board > table > tbody')
    print(soup)
else:
    print(response.status_code)
# Out:
# ﻿
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
#
# <html lang="ko" xml:lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="MSThemeCompatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#0d4e9b" name="theme-color"/>
# <link href="../res/img/favicon.ico" rel="shortcut icon"/>
# <link href="../res/img/favicon.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="../res/font/font.css" rel="stylesheet" type="text/css">
# <link href="../res/css/base.css" rel="stylesheet" type="text/css"/>
# <link href="../res/css/kcgs.css" rel="stylesheet" type="text/css"/>
# <link href="../res/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="../res/css/about.css" rel="stylesheet" type="text/css"/>
# ...
